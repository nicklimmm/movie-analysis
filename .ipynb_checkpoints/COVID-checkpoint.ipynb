# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import requests
import seaborn as sns

# %%
covid_df = pd.read_csv('datasets/daily.csv')
covid_df.head()
# Out:
#        date  states    positive    negative  pending  hospitalizedCurrently  \
# 0  20210307      56  28755524.0  74579770.0  11808.0                40212.0
# 1  20210306      56  28714259.0  74449356.0  11783.0                41401.0
# 2  20210305      56  28654639.0  74307155.0  12213.0                42541.0
# 3  20210304      56  28585852.0  74035238.0  12405.0                44172.0
# 4  20210303      56  28520365.0  73857281.0  11778.0                45462.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                878613.0          8137.0          45475.0
# 1                877887.0          8409.0          45453.0
# 2                877384.0          8634.0          45373.0
# 3                874603.0          8970.0          45293.0
# 4                873073.0          9359.0          45214.0
#
#    onVentilatorCurrently  ...          lastModified recovered  total  posNeg  \
# ...

# %%
covid_df.tail()
# Out:
#          date  states  positive  negative  pending  hospitalizedCurrently  \
# 415  20200117       1       0.0       NaN      NaN                    NaN
# 416  20200116       1       0.0       NaN      NaN                    NaN
# 417  20200115       1       0.0       NaN      NaN                    NaN
# 418  20200114       1       0.0       NaN      NaN                    NaN
# 419  20200113       1       NaN       NaN      NaN                    NaN
#
#      hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 415                     NaN             NaN              NaN
# 416                     NaN             NaN              NaN
# 417                     NaN             NaN              NaN
# 418                     NaN             NaN              NaN
# 419                     NaN             NaN              NaN
#
#      onVentilatorCurrently  ...          lastModified recovered  total  \
# 415                    NaN  ...  2020-01-17T24:00:00Z       NaN      0
# ...

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date                      420 non-null    int64
#  1   states                    420 non-null    int64
#  2   positive                  419 non-null    float64
#  3   negative                  372 non-null    float64
#  4   pending                   369 non-null    float64
#  5   hospitalizedCurrently     356 non-null    float64
#  6   hospitalizedCumulative    369 non-null    float64
#  7   inIcuCurrently            347 non-null    float64
#  8   inIcuCumulative           348 non-null    float64
#  9   onVentilatorCurrently     348 non-null    float64
#  10  onVentilatorCumulative    341 non-null    float64
#  11  dateChecked               420 non-null    object
#  12  death                     392 non-null    float64
# ...

# %%
covid_df = covid_df.drop(['recovered', 'total', 'posNeg', 'hash', 'dateChecked', 'lastModified'], axis=1)
covid_df = covid_df.fillna(0)

covid_df['date'] = pd.to_datetime(covid_df['date'], format='%Y%m%d')
covid_df = covid_df.set_index('date')

covid_df = covid_df.astype('int64')

covid_df
# Out:
#             states  positive  negative  pending  hospitalizedCurrently  \
# date
# 2021-03-07      56  28755524  74579770    11808                  40212
# 2021-03-06      56  28714259  74449356    11783                  41401
# 2021-03-05      56  28654639  74307155    12213                  42541
# 2021-03-04      56  28585852  74035238    12405                  44172
# 2021-03-03      56  28520365  73857281    11778                  45462
# ...            ...       ...       ...      ...                    ...
# 2020-01-17       1         0         0        0                      0
# 2020-01-16       1         0         0        0                      0
# 2020-01-15       1         0         0        0                      0
# 2020-01-14       1         0         0        0                      0
# 2020-01-13       1         0         0        0                      0
#
#             hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# date
# ...

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 420 entries, 2021-03-07 to 2020-01-13
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   states                    420 non-null    int64
#  1   positive                  420 non-null    int64
#  2   negative                  420 non-null    int64
#  3   pending                   420 non-null    int64
#  4   hospitalizedCurrently     420 non-null    int64
#  5   hospitalizedCumulative    420 non-null    int64
#  6   inIcuCurrently            420 non-null    int64
#  7   inIcuCumulative           420 non-null    int64
#  8   onVentilatorCurrently     420 non-null    int64
#  9   onVentilatorCumulative    420 non-null    int64
#  10  death                     420 non-null    int64
#  11  hospitalized              420 non-null    int64
#  12  totalTestResults          420 non-null    int64
# ...

# %%
plt.figure(figsize=(24,12))

plt.plot(covid_df['positive'])
# plt.yscale('log')

# %%
plt.plot(covid_df['death'])

# %%
plt.figure(figsize=(24,12))

plt.plot(covid_df['positiveIncrease'])

# %%
covid_df[['deathIncrease', 'hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease']].describe()
# Out:
#        deathIncrease  hospitalizedIncrease  negativeIncrease  positiveIncrease
# count     420.000000            420.000000        420.000000        420.000000
# mean     1226.528571           2091.935714     177570.880952      68465.533333
# std      1069.934835           1860.308447     121525.950883      68682.100631
# min         0.000000          -2856.000000    -658774.000000          0.000000
# 25%       439.750000            960.000000      79580.500000      22433.250000
# 50%      1018.500000           1812.500000     206920.000000      44670.500000
# 75%      1641.750000           2950.000000     260563.750000      89684.250000
# max      5427.000000          17287.000000     480256.000000     295121.000000
