# %%
import requests as r
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Important Links
# [The Movie DB](https://www.themoviedb.org/) <br>
# [API Documentation](https://developers.themoviedb.org/3/getting-started/introduction)

# %%
API_KEY = 'db6bd34e31c99738cfb114ed7ad6d566'

# %% [markdown]
# # Helper Functions

# %% [markdown]
# # Problems
# - What makes a movie good, bad? How would you define those? (Classification)
# - Can we predict vote count and ratings based on certain criterias? (Regression)
# - Can neural networks work on non-linearly-correlated data?
# - How does it compare to linear regression?

# %% [markdown]
# # Data Extraction

# %%
def compute_top_avg(df, col, percentile):
    try:
        top = df[col].sort_values(ascending=False)[:int(len(df) * percentile), 1]
        return top.sum() / len(top)
    except:
        return np.nan

# %%
def get_popularity_stats(resp, col):
    result = {}
    
    try:
        data = pd.DataFrame(resp.json()[col])

        try:
            result['avg'] = compute_top_avg(data, col='popularity', percentile=0.1)
        except:
            result['avg'] = np.nan

        try:
            result['sum'] = data['popularity'].sum()
        except:
            result['sum'] = np.nan 

        try:
            result['top'] = data['popularity'].max()
        except:
            result['top'] = np.nan

    except KeyError:
        result['avg'] = np.nan
        result['sum'] = np.nan
        result['top'] = np.nan
        
    return result

# %%
def get_movies():
    movie = pd.DataFrame()
    resp = r.get(f"https://api.themoviedb.org/3/discover/movie?api_key={API_KEY}&language=en-US&sort_by=revenue.desc&include_adult=false&include_video=false&page=1")
    total_pages = resp.json()['total_pages']
    
    # Get relevant movie columns
    cols = ['title', 'id', 'popularity', 'vote_count', 'vote_average']
    for i in range(1,total_pages + 1):
        if (i % 50 == 0):
            print('Page', i)
        resp = r.get(f"https://api.themoviedb.org/3/discover/movie?api_key={API_KEY}&language=en-US&sort_by=revenue.desc&include_adult=false&include_video=false&page={i}")
        data = pd.DataFrame(resp.json()['results'])[cols]
        movie = movie.append(data)
    
    movie = movie.reset_index(drop=True)
        
    top_casts_popularity_avg = []
    top_crews_popularity_avg = []
    casts_popularity_sum = []
    crews_popularity_sum = []
    top_cast_popularity = []
    top_crew_popularity = []
    budgets = []
    
    for i in range(len(movie)):
        movie_id = movie['id'][i]
        if (i % 1000 == 0):
            print('Movie', i)
        
        resp = r.get(f'https://api.themoviedb.org/3/movie/{movie_id}/credits?api_key={API_KEY}&language=en-US')
        
        # Get casts popularity statistics from a movie
        casts_popularity_stats = get_popularity_stats(resp, 'cast')
        top_casts_popularity_avg.append(casts_popularity_stats['avg'])
        casts_popularity_sum.append(casts_popularity_stats['sum'])
        top_cast_popularity.append(casts_popularity_stats['top'])
        
        
        # Get crews popularity statistics from a movie
        crews_popularity_stats = get_popularity_stats(resp, 'crew')
        top_crews_popularity_avg.append(crews_popularity_stats['avg'])
        crews_popularity_sum.append(crews_popularity_stats['sum'])
        top_crew_popularity.append(crews_popularity_stats['top'])

        resp = r.get(f'https://api.themoviedb.org/3/movie/{movie_id}?api_key={API_KEY}&language=en-US')
        
        # Get budget from a movie
        try:
            budgets.append(resp.json()['budget'])
        except KeyError:
            budgets.append(np.nan)
        
    movie['top_casts_popularity_avg'] = top_casts_popularity_avg
    movie['top_crews_popularity_avg'] = top_crews_popularity_avg
    movie['casts_popularity_sum'] = casts_popularity_sum
    movie['crews_popularity_sum'] = crews_popularity_sum
    movie['top_cast_popularity'] = top_cast_popularity
    movie['top_crew_popularity'] = top_crew_popularity
    movie['budget'] = budgets

    return movie

# %%
df = get_movies()
df.to_csv('movie-full-dataset.csv')
# Out:
# Page 50
# Page 100
# Page 150
# Page 200
# Page 250
# Page 300
# Page 350
# Page 400
# Page 450
# Page 500
# Movie 0
# <ipython-input-3-ef500f9157b3>:5: RuntimeWarning: invalid value encountered in double_scalars
#   return top.sum() / len(top)
# Movie 100
# Movie 200
# Movie 300
# Movie 400
# Movie 500
# Movie 600
# Movie 700
# Movie 800
# Movie 900
# Movie 1000
# Movie 1100
# Movie 1200
# Movie 1300
# Movie 1400
# Movie 1500
# Movie 1600
# Movie 1700
# Movie 1800
# Movie 1900
# Movie 2000
# Movie 2100
# Movie 2200
# Movie 2300
# Movie 2400
# Movie 2500
# Movie 2600
# Movie 2700
# Movie 2800
# Movie 2900
# Movie 3000
# Movie 3100
# Movie 3200
# Movie 3300
# Movie 3400
# Movie 3500
# Movie 3600
# Movie 3700
# Movie 3800
# Movie 3900
# Movie 4000
# Movie 4100
# Movie 4200
# Movie 4300
# Movie 4400
# Movie 4500
# Movie 4600
# Movie 4700
# Movie 4800
# Movie 4900
# Movie 5000
# Movie 5100
# Movie 5200
# Movie 5300
# Movie 5400
# Movie 5500
# Movie 5600
# Movie 5700
# Movie 5800
# Movie 5900
# Movie 6000
# Movie 6100
# Movie 6200
# Movie 6300
# Movie 6400
# Movie 6500
# Movie 6600
# Movie 6700
# Movie 6800
# Movie 6900
# Movie 7000
# Movie 7100
# Movie 7200
# Movie 7300
# Movie 7400
# Movie 7500
# Movie 7600
# Movie 7700
# Movie 7800
# Movie 7900
# Movie 8000
# Movie 8100
# Movie 8200
# Movie 8300
# Movie 8400
# Movie 8500
# Movie 8600
# Movie 8700
# Movie 8800
# Movie 8900
# Movie 9000
# Movie 9100
# Movie 9200
# Movie 9300
# Movie 9400
# Movie 9500
# Movie 9600
# Movie 9700
# Movie 9800
# Movie 9900

# %%
df = pd.read_csv('movie-full-dataset.csv', index_col=0)
df
# Out:
#                              title      id  popularity  vote_count  \
# 0                Avengers: Endgame  299534     355.688       17650
# 1                           Avatar   19995     109.432       23115
# 2                          Titanic     597     141.721       18920
# 3     Star Wars: The Force Awakens  140607      56.282       15636
# 4           Avengers: Infinity War  299536     374.917       21373
# ...                            ...     ...         ...         ...
# 9995          Behind the Blue Door  425722       1.620          19
# 9996                Insomnia Lover  741028       0.600           0
# 9997                The Last Waltz   13963      10.943         155
# 9998                  The Gigolo 2  378462       2.163           3
# 9999                   In the Fade  423646      17.020         589
#
#       vote_average  top_casts_popularity_avg  top_crews_popularity_avg  \
# 0              8.3                 23.870800                  2.616333
# 1              7.5                 10.457000                  1.533536
# 2              7.9                  8.051364                  2.997000
# 3              7.4                  7.990222                  2.575783
# 4              8.3                 26.473667                  2.235121
# ...            ...                       ...                       ...
# 9995           5.6                  1.380000                       NaN
# 9996           0.0                       NaN                       NaN
# 9997           7.7                  3.424000                  4.680000
# 9998           4.5                       NaN                       NaN
# 9999           7.0                  3.259000                  2.335000
#
#       casts_popularity_sum  crews_popularity_sum  top_cast_popularity  \
# 0                  656.934               505.825               49.553
# 1                   96.592               716.480               11.211
# 2                  195.755               121.917               27.013
# 3                  341.934               242.998               14.324
# 4                  469.885               497.096               49.553
# ...                    ...                   ...                  ...
# 9995                 9.116                 2.400                1.380
# 9996                 2.653                 0.600                1.453
# 9997                32.636                26.680                7.180
# 9998                14.005                 7.618                5.682
# 9999                23.451                20.942                3.724
#
#       top_crew_popularity       budget
# 0                   7.761  356000000.0
# 1                   4.313  237000000.0
# 2                   4.313  200000000.0
# 3                   8.688  245000000.0
# 4                   7.761  300000000.0
# ...                   ...          ...
# 9995                0.600          0.0
# 9996                0.600          0.0
# 9997                7.180          0.0
# 9998                3.104          0.0
# 9999                2.335          0.0
#
# [10000 rows x 12 columns]

# %%
df.head()
# Out:
#                           title      id  popularity  vote_count  vote_average  \
# 0             Avengers: Endgame  299534     355.688       17650           8.3
# 1                        Avatar   19995     109.432       23115           7.5
# 2                       Titanic     597     141.721       18920           7.9
# 3  Star Wars: The Force Awakens  140607      56.282       15636           7.4
# 4        Avengers: Infinity War  299536     374.917       21373           8.3
#
#    top_casts_popularity_avg  top_crews_popularity_avg  casts_popularity_sum  \
# 0                 23.870800                  2.616333               656.934
# 1                 10.457000                  1.533536                96.592
# 2                  8.051364                  2.997000               195.755
# 3                  7.990222                  2.575783               341.934
# 4                 26.473667                  2.235121               469.885
#
#    crews_popularity_sum  top_cast_popularity  top_crew_popularity       budget
# 0               505.825               49.553                7.761  356000000.0
# 1               716.480               11.211                4.313  237000000.0
# 2               121.917               27.013                4.313  200000000.0
# 3               242.998               14.324                8.688  245000000.0
# 4               497.096               49.553                7.761  300000000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     10000 non-null  object
#  1   id                        10000 non-null  int64
#  2   popularity                10000 non-null  float64
#  3   vote_count                10000 non-null  int64
#  4   vote_average              10000 non-null  float64
#  5   top_casts_popularity_avg  8792 non-null   float64
#  6   top_crews_popularity_avg  7824 non-null   float64
#  7   casts_popularity_sum      9937 non-null   float64
#  8   crews_popularity_sum      9916 non-null   float64
#  9   top_cast_popularity       9937 non-null   float64
#  10  top_crew_popularity       9916 non-null   float64
#  11  budget                    9991 non-null   float64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 1015.6+ KB

# %% [markdown]
# # Data Cleaning

# %%
cleaned_df = df.dropna().drop(columns=['title', 'id', 'budget'])
cleaned_df
# Out:
#       popularity  vote_count  vote_average  top_casts_popularity_avg  \
# 0        374.029       17609           8.3                 20.576400
# 1        125.045       23102           7.5                  9.935667
# 2         80.521       18905           7.9                  6.459364
# 3         55.784       15628           7.4                  7.449389
# 4        385.144       21348           8.3                 24.528167
# ...          ...         ...           ...                       ...
# 9988       3.002          27           7.0                  2.435000
# 9992       9.127         155           7.7                  3.264000
# 9994      15.953         589           7.0                  4.084500
# 9996      37.724         369           6.0                 10.332000
# 9999       1.400           5           6.8                  4.460000
#
#       top_crews_popularity_avg  casts_popularity_sum  crews_popularity_sum  \
# 0                     2.252843               607.395               418.227
# 1                     1.350804                80.955               672.786
# 2                     2.389667               168.005               108.642
# 3                     2.897652               314.613               222.384
# 4                     2.051621               437.763               456.858
# ...                        ...                   ...                   ...
# 9988                  1.960000                13.615                14.326
# 9992                  3.429000                31.666                22.326
# 9994                  1.560000                21.221                19.468
# 9996                  1.485182                34.770                81.946
# 9999                  2.262000                17.218                14.874
#
#       top_cast_popularity  top_crew_popularity
# 0                  49.261                6.223
# 1                  12.756                3.603
# 2                  16.315                3.603
# 3                  14.148                9.425
# 4                  49.261                6.223
# ...                   ...                  ...
# 9988                2.435                1.960
# 9992                5.667                5.667
# 9994                6.019                1.560
# 9996               10.332                2.155
# 9999                4.460                2.262
#
# [7385 rows x 9 columns]

# %%
cleaned_df = cleaned_df[[x for x in cleaned_df.columns if x not in ['vote_count', 'vote_average']] + ['vote_count', 'vote_average']]
cleaned_df.to_csv('movie-dataset.csv')

# %%
cleaned_df = pd.read_csv('cleaned-movie-dataset.csv', index_col=0)
cleaned_df
# Out:
#       popularity  top_casts_popularity_avg  top_crews_popularity_avg  \
# 0        374.029                 20.576400                  2.252843
# 1        125.045                  9.935667                  1.350804
# 2         80.521                  6.459364                  2.389667
# 3         55.784                  7.449389                  2.897652
# 4        385.144                 24.528167                  2.051621
# ...          ...                       ...                       ...
# 9988       3.002                  2.435000                  1.960000
# 9992       9.127                  3.264000                  3.429000
# 9994      15.953                  4.084500                  1.560000
# 9996      37.724                 10.332000                  1.485182
# 9999       1.400                  4.460000                  2.262000
#
#       casts_popularity_sum  crews_popularity_sum  top_cast_popularity  \
# 0                  607.395               418.227               49.261
# 1                   80.955               672.786               12.756
# 2                  168.005               108.642               16.315
# 3                  314.613               222.384               14.148
# 4                  437.763               456.858               49.261
# ...                    ...                   ...                  ...
# 9988                13.615                14.326                2.435
# 9992                31.666                22.326                5.667
# 9994                21.221                19.468                6.019
# 9996                34.770                81.946               10.332
# 9999                17.218                14.874                4.460
#
#       top_crew_popularity  vote_count  vote_average
# 0                   6.223       17609           8.3
# 1                   3.603       23102           7.5
# 2                   3.603       18905           7.9
# 3                   9.425       15628           7.4
# 4                   6.223       21348           8.3
# ...                   ...         ...           ...
# 9988                1.960          27           7.0
# 9992                5.667         155           7.7
# 9994                1.560         589           7.0
# 9996                2.155         369           6.0
# 9999                2.262           5           6.8
#
# [7385 rows x 9 columns]

# %% [markdown]
# We can see that the data are skewed and normal.

# %%
sb.pairplot(cleaned_df)

# %%
X = cleaned_df.iloc[:, :-2]
Y = cleaned_df.iloc[:, -2:]

# %% [markdown]
# Maybe we should split the dataset into 3
# 1. Training set (60%)
# 2. Validation set (20%)
# 3. Testing set (20%)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
sb.histplot(data=Y_train['vote_average'], binwidth=0.5)
# Out:
# <AxesSubplot:xlabel='vote_average', ylabel='Count'>

# %%
sb.histplot(data=Y_train['vote_count'], binwidth=1000)
# Out:
# <AxesSubplot:xlabel='vote_count', ylabel='Count'>

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-0.14329347, -0.57232721, -0.6018916 , ..., -0.68932827,
#         -0.70654619, -0.64273676],
#        [-0.03539961, -0.8813623 , -0.38612739, ..., -0.22481936,
#         -0.90498792, -0.52538829],
#        [ 0.00972186, -0.33026496, -0.06917721, ..., -0.42995222,
#         -0.27443639, -0.2580496 ],
#        ...,
#        [-0.12171469,  3.09243583, -0.68075713, ..., -0.65288424,
#          1.64672026, -0.68562965],
#        [-0.06408744, -0.07283096,  1.9475981 , ..., -0.1352532 ,
#         -0.14806189,  0.74386353],
#        [-0.09210982, -0.71175872, -0.24352461, ..., -0.04954189,
#         -0.54245015, -0.28313789]])

# %%
model = Sequential()

# Hidden Layers
model.add(Dense(units=32, activation='relu', input_dim=7))
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=32, activation='relu'))

# Output Layer
model.add(Dense(units=2))

# %% [markdown]
# # Consideration
# - Use Huber loss function that is less sensitive to outliers in data than the squared error loss <br>
#     [Which loss functions to choose?](https://heartbeat.fritz.ai/5-regression-loss-functions-all-machine-learners-should-know-4fb140e9d4b0)
# - Try other loss functions
# - Use metrics
# - Overfit first, then regularize the model

# %%
# Compile
model.compile(optimizer='adam', loss='mean_squared_error')

# Fit
model.fit(X_train, Y_train, batch_size=10, epochs=50)
# Out:
# Epoch 1/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1680139.2380
# Epoch 2/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1732300.3379
# Epoch 3/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1757940.4179
# Epoch 4/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1712288.7207
# Epoch 5/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1832815.1759
# Epoch 6/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1704660.0169
# Epoch 7/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1676733.2349
# Epoch 8/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1859629.3528
# Epoch 9/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1618061.4280
# Epoch 10/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1788004.9019
# Epoch 11/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1658060.2486
# Epoch 12/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1710104.2800
# Epoch 13/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1795856.8718
# Epoch 14/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1777962.5399
# Epoch 15/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1619655.9442
# Epoch 16/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1649066.5498
# Epoch 17/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1738462.2639
# Epoch 18/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1718720.2254
# Epoch 19/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1574807.7546
# Epoch 20/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1661814.9657
# Epoch 21/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1613926.2741
# Epoch 22/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1699634.2126
# Epoch 23/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1690893.7590
# Epoch 24/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1519298.0986
# Epoch 25/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1625265.1636
# Epoch 26/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1560514.6445
# Epoch 27/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1661905.0973
# Epoch 28/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1823333.3638
# Epoch 29/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1347535.6154
# Epoch 30/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1566293.2551
# Epoch 31/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1528305.7143
# Epoch 32/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1522744.8278
# Epoch 33/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1570733.6173
# Epoch 34/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1389644.7975
# Epoch 35/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1649653.0944
# Epoch 36/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1488214.0329
# Epoch 37/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1391711.3105
# Epoch 38/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1280635.6352
# Epoch 39/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1416133.1982
# Epoch 40/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1429834.1370
# Epoch 41/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1510023.7545
# Epoch 42/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1524526.6946
# Epoch 43/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1308289.0428
# Epoch 44/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1293994.6289
# Epoch 45/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1363621.7785
# Epoch 46/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1294272.2757
# Epoch 47/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1386719.7847
# Epoch 48/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1367789.9701
# Epoch 49/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1335634.0896
# Epoch 50/50
# 591/591 [==============================] - 1s 1ms/step - loss: 1414889.3438

# %%
Y_pred = model.predict(X_test)

# %%
Y_pred
# Out:
# array([[ 152.4308  ,    6.087101],
#        [1033.486   ,    6.650053],
#        [1557.05    ,    6.36617 ],
#        ...,
#        [ 238.30453 ,    5.040716],
#        [2213.1702  ,    6.440256],
#        [ 727.357   ,    6.618931]], dtype=float32)

# %%
plt.figure(figsize=(10, 8))

plt.scatter(Y_pred[:, 0], Y_test.iloc[:, 0], color='red')
plt.plot([0, 25000], [0, 25000])

# %% [markdown]
# From here, we should do something with the output layer to make sure that it falls in the range [0, 10]

# %%
plt.figure(figsize=(10, 8))

plt.scatter(Y_pred[:, 1], Y_test.iloc[:, 1], color='red')
plt.plot([0, 10], [0, 10])

# %%
model.save('first-model')
# Out:
# INFO:tensorflow:Assets written to: first-model/assets

# %%
from tensorflow import keras

# %%
loaded_model = keras.models.load_model('first-model')
loaded_model.predict(X_test)
# Out:
# array([[ 152.4308  ,    6.087101],
#        [1033.486   ,    6.650053],
#        [1557.05    ,    6.36617 ],
#        ...,
#        [ 238.30453 ,    5.040716],
#        [2213.1702  ,    6.440256],
#        [ 727.357   ,    6.618931]], dtype=float32)

# %% [markdown]
# ## Classification Model

# %%
class_df = cleaned_df
class_df
# Out:
#       popularity  top_casts_popularity_avg  top_crews_popularity_avg  \
# 0        374.029                 20.576400                  2.252843
# 1        125.045                  9.935667                  1.350804
# 2         80.521                  6.459364                  2.389667
# 3         55.784                  7.449389                  2.897652
# 4        385.144                 24.528167                  2.051621
# ...          ...                       ...                       ...
# 9988       3.002                  2.435000                  1.960000
# 9992       9.127                  3.264000                  3.429000
# 9994      15.953                  4.084500                  1.560000
# 9996      37.724                 10.332000                  1.485182
# 9999       1.400                  4.460000                  2.262000
#
#       casts_popularity_sum  crews_popularity_sum  top_cast_popularity  \
# 0                  607.395               418.227               49.261
# 1                   80.955               672.786               12.756
# 2                  168.005               108.642               16.315
# 3                  314.613               222.384               14.148
# 4                  437.763               456.858               49.261
# ...                    ...                   ...                  ...
# 9988                13.615                14.326                2.435
# 9992                31.666                22.326                5.667
# 9994                21.221                19.468                6.019
# 9996                34.770                81.946               10.332
# 9999                17.218                14.874                4.460
#
#       top_crew_popularity  vote_count  vote_average
# 0                   6.223       17609           8.3
# 1                   3.603       23102           7.5
# 2                   3.603       18905           7.9
# 3                   9.425       15628           7.4
# 4                   6.223       21348           8.3
# ...                   ...         ...           ...
# 9988                1.960          27           7.0
# 9992                5.667         155           7.7
# 9994                1.560         589           7.0
# 9996                2.155         369           6.0
# 9999                2.262           5           6.8
#
# [7385 rows x 9 columns]

# %%
class_df['quality'] = ((class_df[['vote_average']] >= 7).astype(int)).astype('category')
class_df = class_df.drop(columns=['vote_count', 'vote_average'])
class_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-7d24f4f4321e> in <module>
# ----> 1 class_df['quality'] = ((class_df[['vote_average']] >= 7).astype(int)).astype('category')
#       2 class_df = class_df.drop(columns=['vote_count', 'vote_average'])
#       3 class_df
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['vote_average'], dtype='object')] are in the [columns]"

# %%
class_df[['quality']].value_counts()
# Out:
# quality
# 0          5180
# 1          2205
# dtype: int64

# %%
class_df
# Out:
#       popularity  top_casts_popularity_avg  top_crews_popularity_avg  \
# 0        374.029                 20.576400                  2.252843
# 1        125.045                  9.935667                  1.350804
# 2         80.521                  6.459364                  2.389667
# 3         55.784                  7.449389                  2.897652
# 4        385.144                 24.528167                  2.051621
# ...          ...                       ...                       ...
# 9988       3.002                  2.435000                  1.960000
# 9992       9.127                  3.264000                  3.429000
# 9994      15.953                  4.084500                  1.560000
# 9996      37.724                 10.332000                  1.485182
# 9999       1.400                  4.460000                  2.262000
#
#       casts_popularity_sum  crews_popularity_sum  top_cast_popularity  \
# 0                  607.395               418.227               49.261
# 1                   80.955               672.786               12.756
# 2                  168.005               108.642               16.315
# 3                  314.613               222.384               14.148
# 4                  437.763               456.858               49.261
# ...                    ...                   ...                  ...
# 9988                13.615                14.326                2.435
# 9992                31.666                22.326                5.667
# 9994                21.221                19.468                6.019
# 9996                34.770                81.946               10.332
# 9999                17.218                14.874                4.460
#
#       top_crew_popularity  quality
# 0                   6.223        1
# 1                   3.603        1
# 2                   3.603        1
# 3                   9.425        1
# 4                   6.223        1
# ...                   ...      ...
# 9988                1.960        1
# 9992                5.667        1
# 9994                1.560        1
# 9996                2.155        0
# 9999                2.262        0
#
# [7385 rows x 8 columns]

# %%
X = class_df.iloc[:, :-1]
y = class_df.iloc[:, -1]

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
train, validate, test = np.split(class_df.sample(frac=1), [int(.6*len(class_df)), int(.8*len(class_df))])

# %%
X_train, y_train = train.iloc[:, :-1], train.iloc[:, -1]
X_val, y_val = validate.iloc[:, :-1], validate.iloc[:, -1]
X_test, y_test = test.iloc[:, :-1], test.iloc[:, -1]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4431 entries, 690 to 5059
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   popularity                4431 non-null   float64
#  1   top_casts_popularity_avg  4431 non-null   float64
#  2   top_crews_popularity_avg  4431 non-null   float64
#  3   casts_popularity_sum      4431 non-null   float64
#  4   crews_popularity_sum      4431 non-null   float64
#  5   top_cast_popularity       4431 non-null   float64
#  6   top_crew_popularity       4431 non-null   float64
# dtypes: float64(7)
# memory usage: 436.9 KB

# %%
sb.countplot(y_train)
# Out:
# /home/nicklimmm/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
# First Class Model

model = Sequential()
model.add(Dense(32, input_dim=7, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(24, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.7506 - accuracy: 0.6814
# Epoch 2/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.6194 - accuracy: 0.6947
# Epoch 3/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.6111 - accuracy: 0.7115
# Epoch 4/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5870 - accuracy: 0.7120
# Epoch 5/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5891 - accuracy: 0.7084
# Epoch 6/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5893 - accuracy: 0.7144
# Epoch 7/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5792 - accuracy: 0.7122
# Epoch 8/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5750 - accuracy: 0.7260
# Epoch 9/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5782 - accuracy: 0.7117
# Epoch 10/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5901 - accuracy: 0.7011
# Epoch 11/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5898 - accuracy: 0.7024
# Epoch 12/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5884 - accuracy: 0.6995
# Epoch 13/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5864 - accuracy: 0.7074
# Epoch 14/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5736 - accuracy: 0.7195
# Epoch 15/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5786 - accuracy: 0.7143
# Epoch 16/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5745 - accuracy: 0.7121
# Epoch 17/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5868 - accuracy: 0.7017
# Epoch 18/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5741 - accuracy: 0.7127
# Epoch 19/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5793 - accuracy: 0.7043
# Epoch 20/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5770 - accuracy: 0.7057
# Epoch 21/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5704 - accuracy: 0.7146
# Epoch 22/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5813 - accuracy: 0.7067
# Epoch 23/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5730 - accuracy: 0.7091
# Epoch 24/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5885 - accuracy: 0.6968
# Epoch 25/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5791 - accuracy: 0.7076
# Epoch 26/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5628 - accuracy: 0.7165
# Epoch 27/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5716 - accuracy: 0.7004
# Epoch 28/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5641 - accuracy: 0.7177
# Epoch 29/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5664 - accuracy: 0.7108
# Epoch 30/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5780 - accuracy: 0.7056
# Epoch 31/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5731 - accuracy: 0.7033
# Epoch 32/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5744 - accuracy: 0.7041
# Epoch 33/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5729 - accuracy: 0.7072
# Epoch 34/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5721 - accuracy: 0.7100
# Epoch 35/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5701 - accuracy: 0.7105
# Epoch 36/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5692 - accuracy: 0.7113
# Epoch 37/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5741 - accuracy: 0.7017
# Epoch 38/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5724 - accuracy: 0.7007
# Epoch 39/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5726 - accuracy: 0.7093
# Epoch 40/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5636 - accuracy: 0.7150
# Epoch 41/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5656 - accuracy: 0.7039
# Epoch 42/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5605 - accuracy: 0.7175
# Epoch 43/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5695 - accuracy: 0.7078
# Epoch 44/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5845 - accuracy: 0.6950
# Epoch 45/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5677 - accuracy: 0.7118
# Epoch 46/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5654 - accuracy: 0.7184
# Epoch 47/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5740 - accuracy: 0.7061
# Epoch 48/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5715 - accuracy: 0.7147
# Epoch 49/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5449 - accuracy: 0.7299
# Epoch 50/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5590 - accuracy: 0.7237
# Epoch 51/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5693 - accuracy: 0.7092
# Epoch 52/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5527 - accuracy: 0.7199
# Epoch 53/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5717 - accuracy: 0.7082
# Epoch 54/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5672 - accuracy: 0.7111
# Epoch 55/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5661 - accuracy: 0.7226
# Epoch 56/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5611 - accuracy: 0.7218
# Epoch 57/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5623 - accuracy: 0.7199
# Epoch 58/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5537 - accuracy: 0.7223
# Epoch 59/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5647 - accuracy: 0.7181
# Epoch 60/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5604 - accuracy: 0.7127
# Epoch 61/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5723 - accuracy: 0.7176
# Epoch 62/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5587 - accuracy: 0.7218
# Epoch 63/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5678 - accuracy: 0.7083
# Epoch 64/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5596 - accuracy: 0.7197
# Epoch 65/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5538 - accuracy: 0.7254
# Epoch 66/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5575 - accuracy: 0.7233
# Epoch 67/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5507 - accuracy: 0.7281
# Epoch 68/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5511 - accuracy: 0.7226
# Epoch 69/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5560 - accuracy: 0.7280
# Epoch 70/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5502 - accuracy: 0.7293
# Epoch 71/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5577 - accuracy: 0.7111
# Epoch 72/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5572 - accuracy: 0.7180
# Epoch 73/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5572 - accuracy: 0.7213
# Epoch 74/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5576 - accuracy: 0.7193
# Epoch 75/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5516 - accuracy: 0.7201
# Epoch 76/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5528 - accuracy: 0.7252
# Epoch 77/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5584 - accuracy: 0.7240
# Epoch 78/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5579 - accuracy: 0.7234
# Epoch 79/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5512 - accuracy: 0.7314
# Epoch 80/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5482 - accuracy: 0.7243
# Epoch 81/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5502 - accuracy: 0.7291
# Epoch 82/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5551 - accuracy: 0.7195
# Epoch 83/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5461 - accuracy: 0.7263
# Epoch 84/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5487 - accuracy: 0.7305
# Epoch 85/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5481 - accuracy: 0.7218
# Epoch 86/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5539 - accuracy: 0.7211
# Epoch 87/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5398 - accuracy: 0.7273
# Epoch 88/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5403 - accuracy: 0.7403
# Epoch 89/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5557 - accuracy: 0.7209
# Epoch 90/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5515 - accuracy: 0.7227
# Epoch 91/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5419 - accuracy: 0.7259
# Epoch 92/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5445 - accuracy: 0.7293
# Epoch 93/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5502 - accuracy: 0.7295
# Epoch 94/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5412 - accuracy: 0.7293
# Epoch 95/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5409 - accuracy: 0.7292
# Epoch 96/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5399 - accuracy: 0.7370
# Epoch 97/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5451 - accuracy: 0.7210
# Epoch 98/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5491 - accuracy: 0.7209
# Epoch 99/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5502 - accuracy: 0.7243
# Epoch 100/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5351 - accuracy: 0.7362
# Epoch 101/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5330 - accuracy: 0.7387
# Epoch 102/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7344
# Epoch 103/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5498 - accuracy: 0.7209
# Epoch 104/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5439 - accuracy: 0.7246
# Epoch 105/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5428 - accuracy: 0.7327
# Epoch 106/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5446 - accuracy: 0.7253
# Epoch 107/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5468 - accuracy: 0.7294
# Epoch 108/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7354
# Epoch 109/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5447 - accuracy: 0.7292
# Epoch 110/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5237 - accuracy: 0.7498
# Epoch 111/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5534 - accuracy: 0.7244
# Epoch 112/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5362 - accuracy: 0.7329
# Epoch 113/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5315 - accuracy: 0.7338
# Epoch 114/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5416 - accuracy: 0.7291
# Epoch 115/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5439 - accuracy: 0.7269
# Epoch 116/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5349 - accuracy: 0.7405
# Epoch 117/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5528 - accuracy: 0.7189
# Epoch 118/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5333 - accuracy: 0.7410
# Epoch 119/150
# 444/444 [==============================] - 1s 3ms/step - loss: 0.5406 - accuracy: 0.7258
# Epoch 120/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5322 - accuracy: 0.7372
# Epoch 121/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5442 - accuracy: 0.7266
# Epoch 122/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7302
# Epoch 123/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5434 - accuracy: 0.7248
# Epoch 124/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5325 - accuracy: 0.7404
# Epoch 125/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5400 - accuracy: 0.7281
# Epoch 126/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5356 - accuracy: 0.7331
# Epoch 127/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5318 - accuracy: 0.7309
# Epoch 128/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5395 - accuracy: 0.7390
# Epoch 129/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5388 - accuracy: 0.7256
# Epoch 130/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5439 - accuracy: 0.7306
# Epoch 131/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5295 - accuracy: 0.7456
# Epoch 132/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5253 - accuracy: 0.7374
# Epoch 133/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5317 - accuracy: 0.7337
# Epoch 134/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5324 - accuracy: 0.7367
# Epoch 135/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5389 - accuracy: 0.7332
# Epoch 136/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5407 - accuracy: 0.7300
# Epoch 137/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5408 - accuracy: 0.7351
# Epoch 138/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7272
# Epoch 139/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5255 - accuracy: 0.7482
# Epoch 140/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5285 - accuracy: 0.7458
# Epoch 141/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5315 - accuracy: 0.7385
# Epoch 142/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5315 - accuracy: 0.7430
# Epoch 143/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5257 - accuracy: 0.7370
# Epoch 144/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5264 - accuracy: 0.7405
# Epoch 145/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7377
# Epoch 146/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5286 - accuracy: 0.7405
# Epoch 147/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5302 - accuracy: 0.7411
# Epoch 148/150
# 444/444 [==============================] - 0s 1ms/step - loss: 0.5339 - accuracy: 0.7371
# Epoch 149/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7365
# Epoch 150/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5265 - accuracy: 0.7353

# %%
_, accuracy = model.evaluate(X_val, y_val)
# Out:
# 47/47 [==============================] - 0s 1ms/step - loss: 0.5992 - accuracy: 0.7123

# %%
# Second Class Model

model = Sequential()
model.add(Dense(32, input_dim=7, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(24, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(5, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.6208 - accuracy: 0.7071
# Epoch 2/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.6036 - accuracy: 0.7055
# Epoch 3/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5959 - accuracy: 0.7068
# Epoch 4/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5922 - accuracy: 0.7068
# Epoch 5/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5899 - accuracy: 0.7071
# Epoch 6/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5876 - accuracy: 0.7071
# Epoch 7/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5872 - accuracy: 0.7057
# Epoch 8/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5909 - accuracy: 0.7066
# Epoch 9/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5874 - accuracy: 0.7082
# Epoch 10/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5843 - accuracy: 0.7073
# Epoch 11/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5855 - accuracy: 0.7062
# Epoch 12/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5828 - accuracy: 0.7064
# Epoch 13/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5816 - accuracy: 0.7077
# Epoch 14/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5839 - accuracy: 0.7073
# Epoch 15/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5831 - accuracy: 0.7062
# Epoch 16/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5798 - accuracy: 0.7071
# Epoch 17/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5792 - accuracy: 0.7082
# Epoch 18/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5824 - accuracy: 0.7050
# Epoch 19/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5788 - accuracy: 0.7057
# Epoch 20/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5803 - accuracy: 0.7050
# Epoch 21/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5799 - accuracy: 0.7055
# Epoch 22/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5797 - accuracy: 0.7046
# Epoch 23/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5776 - accuracy: 0.7082
# Epoch 24/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5789 - accuracy: 0.7071
# Epoch 25/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5761 - accuracy: 0.7071
# Epoch 26/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5762 - accuracy: 0.7075
# Epoch 27/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5744 - accuracy: 0.7066
# Epoch 28/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5737 - accuracy: 0.7080
# Epoch 29/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5764 - accuracy: 0.7053
# Epoch 30/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5746 - accuracy: 0.7080
# Epoch 31/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5727 - accuracy: 0.7080
# Epoch 32/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5735 - accuracy: 0.7077
# Epoch 33/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5735 - accuracy: 0.7064
# Epoch 34/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5736 - accuracy: 0.7059
# Epoch 35/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5729 - accuracy: 0.7066
# Epoch 36/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5696 - accuracy: 0.7084
# Epoch 37/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5698 - accuracy: 0.7071
# Epoch 38/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5699 - accuracy: 0.7080
# Epoch 39/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5705 - accuracy: 0.7082
# Epoch 40/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5701 - accuracy: 0.7080
# Epoch 41/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5687 - accuracy: 0.7077
# Epoch 42/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5689 - accuracy: 0.7053
# Epoch 43/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5672 - accuracy: 0.7066
# Epoch 44/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5670 - accuracy: 0.7066
# Epoch 45/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5652 - accuracy: 0.7075
# Epoch 46/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5659 - accuracy: 0.7066
# Epoch 47/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5640 - accuracy: 0.7077
# Epoch 48/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5655 - accuracy: 0.7059
# Epoch 49/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5655 - accuracy: 0.7073
# Epoch 50/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5661 - accuracy: 0.7071
# Epoch 51/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5666 - accuracy: 0.7075
# Epoch 52/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5640 - accuracy: 0.7075
# Epoch 53/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5618 - accuracy: 0.7068
# Epoch 54/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5661 - accuracy: 0.7073
# Epoch 55/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5611 - accuracy: 0.7075
# Epoch 56/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5636 - accuracy: 0.7059
# Epoch 57/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5602 - accuracy: 0.7062
# Epoch 58/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5608 - accuracy: 0.7107
# Epoch 59/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5588 - accuracy: 0.7195
# Epoch 60/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5609 - accuracy: 0.7193
# Epoch 61/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5604 - accuracy: 0.7199
# Epoch 62/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5624 - accuracy: 0.7123
# Epoch 63/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5581 - accuracy: 0.7165
# Epoch 64/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5601 - accuracy: 0.7188
# Epoch 65/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5598 - accuracy: 0.7163
# Epoch 66/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5551 - accuracy: 0.7195
# Epoch 67/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5559 - accuracy: 0.7220
# Epoch 68/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5566 - accuracy: 0.7190
# Epoch 69/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5531 - accuracy: 0.7276
# Epoch 70/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5564 - accuracy: 0.7249
# Epoch 71/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5535 - accuracy: 0.7267
# Epoch 72/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5530 - accuracy: 0.7217
# Epoch 73/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5535 - accuracy: 0.7249
# Epoch 74/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5517 - accuracy: 0.7240
# Epoch 75/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5536 - accuracy: 0.7233
# Epoch 76/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5520 - accuracy: 0.7238
# Epoch 77/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5525 - accuracy: 0.7260
# Epoch 78/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5506 - accuracy: 0.7265
# Epoch 79/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5537 - accuracy: 0.7242
# Epoch 80/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5496 - accuracy: 0.7211
# Epoch 81/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5488 - accuracy: 0.7296
# Epoch 82/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5481 - accuracy: 0.7262
# Epoch 83/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5495 - accuracy: 0.7235
# Epoch 84/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5484 - accuracy: 0.7244
# Epoch 85/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5513 - accuracy: 0.7199
# Epoch 86/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5463 - accuracy: 0.7253
# Epoch 87/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5466 - accuracy: 0.7231
# Epoch 88/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5457 - accuracy: 0.7247
# Epoch 89/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5506 - accuracy: 0.7195
# Epoch 90/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5473 - accuracy: 0.7231
# Epoch 91/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5491 - accuracy: 0.7224
# Epoch 92/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5466 - accuracy: 0.7283
# Epoch 93/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5409 - accuracy: 0.7305
# Epoch 94/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5457 - accuracy: 0.7267
# Epoch 95/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5443 - accuracy: 0.7294
# Epoch 96/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5437 - accuracy: 0.7242
# Epoch 97/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5443 - accuracy: 0.7281
# Epoch 98/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5455 - accuracy: 0.7269
# Epoch 99/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5457 - accuracy: 0.7267
# Epoch 100/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5462 - accuracy: 0.7247
# Epoch 101/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5445 - accuracy: 0.7256
# Epoch 102/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5403 - accuracy: 0.7296
# Epoch 103/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5407 - accuracy: 0.7301
# Epoch 104/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5408 - accuracy: 0.7346
# Epoch 105/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5390 - accuracy: 0.7314
# Epoch 106/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5409 - accuracy: 0.7319
# Epoch 107/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5374 - accuracy: 0.7378
# Epoch 108/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5437 - accuracy: 0.7238
# Epoch 109/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5403 - accuracy: 0.7323
# Epoch 110/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5358 - accuracy: 0.7278
# Epoch 111/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7326
# Epoch 112/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5410 - accuracy: 0.7271
# Epoch 113/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5387 - accuracy: 0.7353
# Epoch 114/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5402 - accuracy: 0.7305
# Epoch 115/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5396 - accuracy: 0.7274
# Epoch 116/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5370 - accuracy: 0.7321
# Epoch 117/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5386 - accuracy: 0.7341
# Epoch 118/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5355 - accuracy: 0.7317
# Epoch 119/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5355 - accuracy: 0.7269
# Epoch 120/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5437 - accuracy: 0.7319
# Epoch 121/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5346 - accuracy: 0.7335
# Epoch 122/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5371 - accuracy: 0.7393
# Epoch 123/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5340 - accuracy: 0.7346
# Epoch 124/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5352 - accuracy: 0.7366
# Epoch 125/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5354 - accuracy: 0.7337
# Epoch 126/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5292 - accuracy: 0.7344
# Epoch 127/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5367 - accuracy: 0.7371
# Epoch 128/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5308 - accuracy: 0.7355
# Epoch 129/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5320 - accuracy: 0.7405
# Epoch 130/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5318 - accuracy: 0.7364
# Epoch 131/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5286 - accuracy: 0.7375
# Epoch 132/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5305 - accuracy: 0.7425
# Epoch 133/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5278 - accuracy: 0.7402
# Epoch 134/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5272 - accuracy: 0.7407
# Epoch 135/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5284 - accuracy: 0.7439
# Epoch 136/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5260 - accuracy: 0.7425
# Epoch 137/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5301 - accuracy: 0.7391
# Epoch 138/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5281 - accuracy: 0.7416
# Epoch 139/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5282 - accuracy: 0.7452
# Epoch 140/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5248 - accuracy: 0.7432
# Epoch 141/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5261 - accuracy: 0.7416
# Epoch 142/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5240 - accuracy: 0.7405
# Epoch 143/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5276 - accuracy: 0.7380
# Epoch 144/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7375
# Epoch 145/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5234 - accuracy: 0.7448
# Epoch 146/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5207 - accuracy: 0.7470
# Epoch 147/150
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5247 - accuracy: 0.7454
# Epoch 148/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5262 - accuracy: 0.7450
# Epoch 149/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5243 - accuracy: 0.7407
# Epoch 150/150
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5191 - accuracy: 0.7470

# %%
_, accuracy = model.evaluate(X_val, y_val)
# Out:
# 47/47 [==============================] - 0s 924us/step - loss: 0.6222 - accuracy: 0.7217

# %% [markdown]
# Overfits

# %%
# Third Class Model

model = Sequential()
model.add(Dense(64, input_dim=7, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.6994 - accuracy: 0.6684
# Epoch 2/100
# 444/444 [==============================] - 1s 1ms/step - loss: 0.6053 - accuracy: 0.7063
# Epoch 3/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.6322 - accuracy: 0.6937
# Epoch 4/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5940 - accuracy: 0.7060
# Epoch 5/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.6073 - accuracy: 0.6959
# Epoch 6/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5953 - accuracy: 0.6980
# Epoch 7/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5889 - accuracy: 0.7061
# Epoch 8/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5925 - accuracy: 0.7036
# Epoch 9/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5777 - accuracy: 0.7127
# Epoch 10/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5897 - accuracy: 0.7028
# Epoch 11/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5927 - accuracy: 0.6987
# Epoch 12/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5863 - accuracy: 0.7001
# Epoch 13/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5866 - accuracy: 0.7056
# Epoch 14/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5801 - accuracy: 0.7052
# Epoch 15/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5714 - accuracy: 0.7089
# Epoch 16/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5805 - accuracy: 0.7080
# Epoch 17/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5599 - accuracy: 0.7260
# Epoch 18/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5846 - accuracy: 0.7031
# Epoch 19/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5754 - accuracy: 0.7084
# Epoch 20/100
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5777 - accuracy: 0.7046
# Epoch 21/100
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5644 - accuracy: 0.7160
# Epoch 22/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5802 - accuracy: 0.6961
# Epoch 23/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5800 - accuracy: 0.7049
# Epoch 24/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5662 - accuracy: 0.7176
# Epoch 25/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5735 - accuracy: 0.7064
# Epoch 26/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5683 - accuracy: 0.7088
# Epoch 27/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5689 - accuracy: 0.7125
# Epoch 28/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5741 - accuracy: 0.7120
# Epoch 29/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5665 - accuracy: 0.7076
# Epoch 30/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5659 - accuracy: 0.7118
# Epoch 31/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5656 - accuracy: 0.7111
# Epoch 32/100
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5618 - accuracy: 0.7186
# Epoch 33/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5652 - accuracy: 0.7077
# Epoch 34/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5798 - accuracy: 0.7075
# Epoch 35/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5656 - accuracy: 0.7118
# Epoch 36/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5650 - accuracy: 0.7116
# Epoch 37/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5648 - accuracy: 0.7112
# Epoch 38/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5512 - accuracy: 0.7293
# Epoch 39/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5615 - accuracy: 0.7138
# Epoch 40/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5487 - accuracy: 0.7234
# Epoch 41/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5559 - accuracy: 0.7162
# Epoch 42/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5631 - accuracy: 0.7216
# Epoch 43/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5618 - accuracy: 0.7119
# Epoch 44/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5430 - accuracy: 0.7317
# Epoch 45/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5559 - accuracy: 0.7195
# Epoch 46/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5501 - accuracy: 0.7247
# Epoch 47/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5553 - accuracy: 0.7245
# Epoch 48/100
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5538 - accuracy: 0.7279
# Epoch 49/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5560 - accuracy: 0.7165
# Epoch 50/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5542 - accuracy: 0.7287
# Epoch 51/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5557 - accuracy: 0.7119
# Epoch 52/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5488 - accuracy: 0.7216
# Epoch 53/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5497 - accuracy: 0.7320
# Epoch 54/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5500 - accuracy: 0.7217
# Epoch 55/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5553 - accuracy: 0.7333
# Epoch 56/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5529 - accuracy: 0.7235
# Epoch 57/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5390 - accuracy: 0.7231
# Epoch 58/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5406 - accuracy: 0.7373
# Epoch 59/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5443 - accuracy: 0.7365
# Epoch 60/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5346 - accuracy: 0.7330
# Epoch 61/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5406 - accuracy: 0.7314
# Epoch 62/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5341 - accuracy: 0.7375
# Epoch 63/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5246 - accuracy: 0.7392
# Epoch 64/100
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5392 - accuracy: 0.7294
# Epoch 65/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5407 - accuracy: 0.7287
# Epoch 66/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5268 - accuracy: 0.7366
# Epoch 67/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5270 - accuracy: 0.7411
# Epoch 68/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5259 - accuracy: 0.7415
# Epoch 69/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5354 - accuracy: 0.7331
# Epoch 70/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5378 - accuracy: 0.7254
# Epoch 71/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5167 - accuracy: 0.7425
# Epoch 72/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5248 - accuracy: 0.7381
# Epoch 73/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5280 - accuracy: 0.7390
# Epoch 74/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5174 - accuracy: 0.7476
# Epoch 75/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5145 - accuracy: 0.7513
# Epoch 76/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5201 - accuracy: 0.7453
# Epoch 77/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5064 - accuracy: 0.7486
# Epoch 78/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5133 - accuracy: 0.7529
# Epoch 79/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5162 - accuracy: 0.7440
# Epoch 80/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5154 - accuracy: 0.7467
# Epoch 81/100
# 444/444 [==============================] - 1s 1ms/step - loss: 0.4994 - accuracy: 0.7640
# Epoch 82/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5241 - accuracy: 0.7445
# Epoch 83/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.4988 - accuracy: 0.7599
# Epoch 84/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.4946 - accuracy: 0.7646
# Epoch 85/100
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5067 - accuracy: 0.7480
# Epoch 86/100
# 444/444 [==============================] - 1s 1ms/step - loss: 0.4908 - accuracy: 0.7670
# Epoch 87/100
# 444/444 [==============================] - 1s 1ms/step - loss: 0.5029 - accuracy: 0.7532
# Epoch 88/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5170 - accuracy: 0.7472
# Epoch 89/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5156 - accuracy: 0.7456
# Epoch 90/100
# 444/444 [==============================] - 1s 1ms/step - loss: 0.4878 - accuracy: 0.7653
# Epoch 91/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.4913 - accuracy: 0.7671
# Epoch 92/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.4946 - accuracy: 0.7576
# Epoch 93/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.5005 - accuracy: 0.7558
# Epoch 94/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.4981 - accuracy: 0.7502
# Epoch 95/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.4919 - accuracy: 0.7627
# Epoch 96/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.4991 - accuracy: 0.7525
# Epoch 97/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.4720 - accuracy: 0.7735
# Epoch 98/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.4923 - accuracy: 0.7585
# Epoch 99/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.4941 - accuracy: 0.7608
# Epoch 100/100
# 444/444 [==============================] - 1s 2ms/step - loss: 0.4820 - accuracy: 0.7740

# %%
_, accuracy = model.evaluate(X_val, y_val)
# Out:
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6621 - accuracy: 0.6960
