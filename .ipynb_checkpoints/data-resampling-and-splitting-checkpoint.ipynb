# %% [markdown]
# # References
# - [Handling imbalanced data (kdnuggets)](https://www.kdnuggets.com/2017/06/7-techniques-handle-imbalanced-data.html)
# - [Resampling strategies for imbalanced datasets (Kaggle)](https://www.kaggle.com/rafjaa/resampling-strategies-for-imbalanced-datasets)
# - [Handling Imbalanced Data (TensorFlow)](https://www.tensorflow.org/tutorials/structured_data/imbalanced_data)

# %% [markdown]
# # Import modules

# %%
# For data processing
import numpy as np
import pandas as pd

# For data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# For data splitting
from sklearn.model_selection import train_test_split

# For handling imbalanced dataset
from imblearn.combine import SMOTETomek
from imblearn.combine import SMOTEENN
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# %% [markdown]
# # Data Splitting

# %%
# Select several columns
cols = ['popularity', 'original_language', 'casts_popularity_sum',
        'crews_popularity_sum', 'genres', 'decade_released', 
        'budget', 'revenue', 'vote_count', 'vote_average']

df = pd.read_csv('cleaned-movie-dataset.csv', index_col=0)[cols]

# Create a new column 'in_en', 1 if the original language is in English and 0 otherwise
df['in_en'] = (df['original_language'] == 'en').astype('int64')

df = df.drop(columns=['original_language'])

# Rearrange columns
df = df[['popularity', 'casts_popularity_sum', 'crews_popularity_sum', 
         'budget', 'decade_released', 'genres', 
         'revenue', 'vote_count', 'vote_average']]

df.head()
# Out:
#    popularity  casts_popularity_sum  crews_popularity_sum       budget  \
# 0     283.822               755.450               473.269  356000000.0
# 1     102.112               108.804               878.826  237000000.0
# 2      86.808               201.581               122.649  200000000.0
# 3      53.930               391.303               235.947  245000000.0
# 4     299.524               528.712               501.005  300000000.0
#
#   decade_released                                             genres  \
# 0           2010s         ['Adventure', 'Science Fiction', 'Action']
# 1           2000s  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 2           1990s                               ['Drama', 'Romance']
# 3           2010s  ['Action', 'Adventure', 'Science Fiction', 'Fa...
# 4           2010s         ['Adventure', 'Action', 'Science Fiction']
#
#         revenue  vote_count  vote_average
# 0  2.797801e+09       17799           8.3
# 1  2.787965e+09       23178           7.5
# 2  2.187464e+09       18982           7.9
# 3  2.068224e+09       15675           7.4
# 4  2.046240e+09       21489           8.3

# %%
# Split the DF into predictors and response
X, y = df.iloc[:, :-1], df.iloc[:, -1]

# Define good as vote_average >= 7.2 (80% percentile)
y = (y >= 7.2).astype('int64')

# Split the dataset into 70% train and 30% test set
# Set random_state for reproducibility
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=20)

# %%
print("Good vs Not Good Movies Train Set Proportion")
print(y_train.value_counts()[1], ':', y_train.value_counts()[0])
# Out:
# Good vs Not Good Movies Train Set Proportion
# 1018 : 3931

# %%
train_df = pd.concat([X_train, y_train], axis=1).rename(columns={'vote_average': 'is_good'})
train_df.head()
# Out:
#       popularity  casts_popularity_sum  crews_popularity_sum      budget  \
# 5527       1.680                34.059                 8.671   3300000.0
# 3263      18.013                46.018                 9.456  26000000.0
# 1022      17.237               182.113               198.986  65000000.0
# 4603      11.931               110.585                44.527  20000000.0
# 2733      14.717                99.835                75.898  51000000.0
#
#      decade_released                                             genres  \
# 5527           2010s                      ['Comedy', 'Action', 'Drama']
# 3263           2010s  ['Thriller', 'Adventure', 'Mystery', 'Fantasy'...
# 1022           2000s                   ['Drama', 'History', 'Thriller']
# 4603           2000s                    ['Action', 'Drama', 'Thriller']
# 2733           2000s                               ['Comedy', 'Family']
#
#           revenue  vote_count  is_good
# 5527   10000000.0           8        0
# 3263   34592118.0         200        0
# 1022  163247198.0        1122        0
# 4603   16605763.0         129        0
# 2733   47231070.0         405        0

# %%
train_df.to_csv('train.csv')

# %% [markdown]
# ## Random Oversampling on training data

# %%
# Define oversampling strategy (creates 1:2 ratio)
over_smp = RandomOverSampler(sampling_strategy=0.5, random_state=20)

# Fit and apply the transform
X_res, y_res = over_smp.fit_resample(X_train, y_train)

# %%
print("Good vs Not Good Movies Train Set Proportion (After oversampling)")
print(y_res.value_counts()[1], ':', y_res.value_counts()[0])
# Out:
# Good vs Not Good Movies Train Set Proportion (After oversampling)
# 1965 : 3931

# %%
# Combine the X and y to a single DF and rename column
oversampled_train_df = pd.concat([X_res, y_res], axis=1).rename(columns={'vote_average': 'is_good'})
oversampled_train_df.head()
# Out:
#    popularity  casts_popularity_sum  crews_popularity_sum      budget  \
# 0       1.680                34.059                 8.671   3300000.0
# 1      18.013                46.018                 9.456  26000000.0
# 2      17.237               182.113               198.986  65000000.0
# 3      11.931               110.585                44.527  20000000.0
# 4      14.717                99.835                75.898  51000000.0
#
#   decade_released                                             genres  \
# 0           2010s                      ['Comedy', 'Action', 'Drama']
# 1           2010s  ['Thriller', 'Adventure', 'Mystery', 'Fantasy'...
# 2           2000s                   ['Drama', 'History', 'Thriller']
# 3           2000s                    ['Action', 'Drama', 'Thriller']
# 4           2000s                               ['Comedy', 'Family']
#
#        revenue  vote_count  is_good
# 0   10000000.0           8        0
# 1   34592118.0         200        0
# 2  163247198.0        1122        0
# 3   16605763.0         129        0
# 4   47231070.0         405        0

# %%
# Save as csv
oversampled_train_df.to_csv('oversampled-train.csv')

# %% [markdown]
# ## SMOTETomek Resampling on training data
# This only applies for numerical variables.

# %%
# Select numerical variables only
X_train = X_train[['popularity', 'casts_popularity_sum',
                   'crews_popularity_sum', 'budget',
                   'revenue', 'vote_count']]
X_train.head()
# Out:
#       popularity  casts_popularity_sum  crews_popularity_sum      budget  \
# 5527       1.680                34.059                 8.671   3300000.0
# 3263      18.013                46.018                 9.456  26000000.0
# 1022      17.237               182.113               198.986  65000000.0
# 4603      11.931               110.585                44.527  20000000.0
# 2733      14.717                99.835                75.898  51000000.0
#
#           revenue  vote_count
# 5527   10000000.0           8
# 3263   34592118.0         200
# 1022  163247198.0        1122
# 4603   16605763.0         129
# 2733   47231070.0         405

# %%
# Set random_state for reproducibility
smt = SMOTETomek(random_state=20)
X_res, y_res = smt.fit_resample(X_train, y_train)

# %%
print("Good vs Not Good Movies Train Set Proportion (After SMOTETomek resampling)")
print(y_res.value_counts()[1], ':', y_res.value_counts()[0])
# Out:
# Good vs Not Good Movies Train Set Proportion (After SMOTETomek resampling)
# 3431 : 3431

# %%
# Combine the X and y to a single DF and rename column
smotetomek_train_df = pd.concat([X_res, y_res], axis=1).rename(columns={'vote_average': 'is_good'})
smotetomek_train_df.head()
# Out:
#    popularity  casts_popularity_sum  crews_popularity_sum      budget  \
# 0       1.680                34.059                 8.671   3300000.0
# 1      18.013                46.018                 9.456  26000000.0
# 2      11.931               110.585                44.527  20000000.0
# 3      14.717                99.835                75.898  51000000.0
# 4      23.357                99.896                62.278  32000000.0
#
#       revenue  vote_count  is_good
# 0  10000000.0           8        0
# 1  34592118.0         200        0
# 2  16605763.0         129        0
# 3  47231070.0         405        0
# 4  83615414.0         897        0

# %%
# Save as csv
smotetomek_train_df.to_csv('smotetomek-train.csv')

# %% [markdown]
# ## SMOTEENN Resampling on training data
# Similar with SMOTETomek resampling, this only applies for numerical variables.

# %%
X_train = X_train[['popularity', 'casts_popularity_sum',
                   'crews_popularity_sum', 'budget',
                   'revenue', 'vote_count']]
X_train.head()
# Out:
#       popularity  casts_popularity_sum  crews_popularity_sum      budget  \
# 5527       1.680                34.059                 8.671   3300000.0
# 3263      18.013                46.018                 9.456  26000000.0
# 1022      17.237               182.113               198.986  65000000.0
# 4603      11.931               110.585                44.527  20000000.0
# 2733      14.717                99.835                75.898  51000000.0
#
#           revenue  vote_count
# 5527   10000000.0           8
# 3263   34592118.0         200
# 1022  163247198.0        1122
# 4603   16605763.0         129
# 2733   47231070.0         405

# %%
# Set random_state for reproducibility
sme = SMOTEENN(random_state=20)
X_res, y_res = sme.fit_resample(X_train, y_train)

# %%
print("Good vs Not Good Movies Train Set Proportion (After SMOTEENN resampling)")
print(y_res.value_counts()[1], ':', y_res.value_counts()[0])
# Out:
# Good vs Not Good Movies Train Set Proportion (After SMOTEENN resampling)
# 1939 : 1756

# %%
# Combine the X and y to a single DF and rename column
smoteenn_train_df = pd.concat([X_res, y_res], axis=1).rename(columns={'vote_average': 'is_good'})
smoteenn_train_df.head()
# Out:
#    popularity  casts_popularity_sum  crews_popularity_sum      budget  \
# 0       1.680                34.059                 8.671   3300000.0
# 1      11.931               110.585                44.527  20000000.0
# 2      14.717                99.835                75.898  51000000.0
# 3      12.050                33.433                10.263  17500000.0
# 4       7.503                36.672                13.520    160000.0
#
#       revenue  vote_count  is_good
# 0  10000000.0           8        0
# 1  16605763.0         129        0
# 2  47231070.0         405        0
# 3  25024919.0         380        0
# 4   4000000.0          51        0

# %%
# Save as csv
smoteenn_train_df.to_csv('smoteenn-train.csv')

# %% [markdown]
# # Save test data as csv

# %%
# Combine the X and y to a single DF and rename column
test_df = pd.concat([X_test, y_test], axis=1).rename(columns={'vote_average': 'is_good'})
test_df.head()
# Out:
#       popularity  casts_popularity_sum  crews_popularity_sum       budget  \
# 6183      10.639                53.101                21.680    5800000.0
# 786       48.052               100.519                97.495   60000000.0
# 100       37.487               255.221               181.062  170000000.0
# 4763      19.589                83.531                99.984   80000000.0
# 429       27.201               121.827               136.950   40000000.0
#
#      decade_released                                             genres  \
# 6183           2000s                   ['Action', 'Adventure', 'Drama']
# 786            2010s                             ['Action', 'Thriller']
# 100            2010s         ['Action', 'Science Fiction', 'Adventure']
# 4763           2000s         ['Science Fiction', 'Thriller', 'Mystery']
# 429            1980s  ['Adventure', 'Comedy', 'Family', 'Science Fic...
#
#           revenue  vote_count  is_good
# 6183    7000000.0          28        0
# 786   205754447.0        3573        0
# 100   772776600.0       22271        1
# 4763   15071514.0         989        0
# 429   332000000.0        9474        1

# %%
# Save as csv
test_df.to_csv('test.csv')
